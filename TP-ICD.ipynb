# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv('billboard_2000_2018_spotify_lyrics.csv',
                 encoding='iso-8859-1', na_values='unknown')
# 2. Removendo na
df = df.dropna()
df.head()
# Out:
#          date    year               title        simple_title          artist  \
# 1017  1/17/17  2017.0            Unsteady            unsteady   x ambassadors
# 1018  1/17/17  2017.0      Too Much Sauce      too much sauce         dj esco
# 1021  1/17/17  2017.0  Key To The Streets  key to the streets       yfn lucci
# 1024  1/14/17  2017.0    Careless Whisper    careless whisper           wham!
# 1025  1/14/17  2017.0               Faith               faith  george michael
#
#          main_artist  peak_pos  last_pos  weeks  rank  \
# 1017   x ambassadors        20        40     34    39
# 1018         dj esco        50        56     20    50
# 1021       yfn lucci        70         0     11    97
# 1024           wham!         1         0     22    33
# 1025  george michael         1         0     21    47
#
#                             ...                         acousticness  \
# 1017                        ...                               0.1770
# 1018                        ...                               0.0496
# 1021                        ...                               0.1220
# 1024                        ...                               0.2610
# 1025                        ...                               0.0094
#
#      instrumentalness time_signature danceability   key duration_ms loudness  \
# 1017         0.000316            4.0        0.598   9.0    193546.0   -6.134
# 1018         0.000000            4.0        0.960   6.0    223093.0   -6.992
# 1021         0.000000            4.0        0.770   6.0    281987.0   -5.448
# 1024         0.622000            4.0        0.651   2.0    312355.0  -14.651
# 1025         0.000036            4.0        0.887  11.0    193200.0  -11.994
#
#       valence  mode                                             lyrics
# 1017    0.255   0.0  Hold, hold on, hold onto me\r\n'Cause I'm a li...
# 1018    0.186   0.0  That's too much sauce\r\nThat's too much sauce...
# 1021    0.292   0.0  I got money way before the deal\r\nPut my bitc...
# 1024    0.745   0.0  I feel so unsure\r\nAs I take your hand and le...
# 1025    0.607   1.0  Well, I guess it would be nice\r\nIf I could t...
#
# [5 rows x 31 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('billboard_2000_2018_spotify_lyrics.csv',
                 encoding='iso-8859-1', na_values='unknown')
#Colunas retiradas:['year', 'simple_title', 'main_artist', 'spotify_link',
#                   'spotify_id', 'video_link', 'broad_genre', 'analysis_url']

df = df[['date', 'title', 'artist', 'peak_pos', 'last_pos', 'weeks', 'rank', 'change', 'genre', 'energy', 'liveness', 'tempo', 'speechiness', 'acousticness', 'instrumentalness', 'time_signature', 'danceability', 'key','duration_ms', 'loudness', 'valence', 'mode', 'lyrics']]

# Removendo na
df = df.dropna()
df.head()
# Out:
#       date                   title        artist  peak_pos  last_pos  weeks  \
# 1  6/21/18  All Girls Are The Same    Juice WRLD        41        49      5
# 2  6/21/18                All Mine    Kanye West        11        11      2
# 5  6/21/18             Back To You  Selena Gomez        22        31      5
# 7  6/21/18              Be Careful       Cardi B        11        25     11
# 8  6/21/18         Beautiful Crazy    Luke Combs        58        77      4
#
#    rank change                                       genre  energy  ...  \
# 1    41      8                                    [u'rap']   0.529  ...
# 2    31    -20                        [u'pop rap', u'rap']   0.308  ...
# 5    22      9    [u'dance pop', u'pop', u'post-teen pop']   0.724  ...
# 7    23      2                            [u'pop', u'rap']   0.568  ...
# 8    93    -16  [u'contemporary country', u'country road']   0.402  ...
#
#    acousticness  instrumentalness  time_signature  danceability   key  \
# ...
